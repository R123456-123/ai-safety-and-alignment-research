# %% [markdown]
# <a href="https://colab.research.google.com/github/R123456-123/ai-safety-and-alignment-research/blob/main/react_agent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def run_agent_loop(query: str, tools: list):
    messages = [{"role": "user", "content": query}]

    while True:
        # step 1: here think and act
        response = llm.invoke(messages, tools=tools)
        messages.append(response)

        if not response.tool_calls:
            # The model emitted a "Finish" action
            return response.content

        # step 2: here that observe
        for tool_call in response.tool_calls:
            result = execute_tool(tool_call)
            messages.append({
                "role": "tool",
                "tool_call_id": tool_call.id,
                "content": str(result)
            })
